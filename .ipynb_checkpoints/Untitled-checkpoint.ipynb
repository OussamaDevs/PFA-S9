# %%
import numpy as np
import pandas as pd
import joblib
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv1D, Dense, Flatten, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import xgboost as xgb
import matplotlib.pyplot as plt

# %%
# Load scaled dataset
df = pd.read_csv("scaled_data.csv")

# Load scaler (for inverse transformation)
target_scaler = joblib.load("target_scaler.pkl")

# Define target variable (e.g., predicting "Close" price)
target_col = "Close"
features = df.drop(columns=["Date", target_col])  # Exclude 'Date' and target from features
target = df[target_col]

# Convert to NumPy arrays
X = features.values
y = target.values

# %%
# Create sequences (time-series window)
def create_sequences(X, y, time_steps=30):
    X_seq, y_seq = [], []
    for i in range(len(X) - time_steps):
        X_seq.append(X[i : i + time_steps])  # Last 'time_steps' inputs
        y_seq.append(y[i + time_steps])  # Predict the next value
    return np.array(X_seq), np.array(y_seq)

# %%
# Define time step window
TIME_STEPS = 30

# Prepare sequences
X_seq, y_seq = create_sequences(X, y, time_steps=TIME_STEPS)

# Split into train & test sets
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)

# Reshape for CNN (Conv1D requires 3D input: (samples, time steps, features))
print("Training shape:", X_train.shape, "Test shape:", X_test.shape)
# Out:
# Training shape: (1063, 30, 12) Test shape: (266, 30, 12)

# %%
# Define CNN model
cnn = Sequential([
    Conv1D(filters=64, kernel_size=3, activation="relu", input_shape=(TIME_STEPS, X.shape[1])),
    Dropout(0.2),
    Conv1D(filters=32, kernel_size=3, activation="relu"),
    Flatten(),
    Dense(32, activation="relu", name="feature_layer"),  # Feature extraction layer
    Dense(1)  # Final output layer (will be ignored for XGBoost)
])

# Compile CNN model
cnn.compile(optimizer="adam", loss="mse", metrics=["mae"])

# Train CNN model
cnn.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# C:\Users\Aleix\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0306 - mae: 0.1159 - val_loss: 0.0026 - val_mae: 0.0408
# Epoch 2/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0042 - mae: 0.0438 - val_loss: 9.8845e-04 - val_mae: 0.0207
# Epoch 3/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0022 - mae: 0.0308 - val_loss: 0.0023 - val_mae: 0.0357
# Epoch 4/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0028 - mae: 0.0350 - val_loss: 9.3771e-04 - val_mae: 0.0202
# Epoch 5/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015 - mae: 0.0264 - val_loss: 8.4295e-04 - val_mae: 0.0187
# Epoch 6/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0019 - mae: 0.0276 - val_loss: 8.2818e-04 - val_mae: 0.0182
# Epoch 7/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - mae: 0.0239 - val_loss: 6.9961e-04 - val_mae: 0.0180
# Epoch 8/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0019 - mae: 0.0284 - val_loss: 9.5737e-04 - val_mae: 0.0195
# Epoch 9/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0013 - mae: 0.0227 - val_loss: 7.5287e-04 - val_mae: 0.0197
# Epoch 10/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011 - mae: 0.0224 - val_loss: 0.0014 - val_mae: 0.0230
# Epoch 11/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0014 - mae: 0.0236 - val_loss: 0.0013 - val_mae: 0.0224
# Epoch 12/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013 - mae: 0.0226 - val_loss: 0.0019 - val_mae: 0.0261
# Epoch 13/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0011 - mae: 0.0204 - val_loss: 9.4726e-04 - val_mae: 0.0176
# Epoch 14/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.5954e-04 - mae: 0.0196 - val_loss: 5.7896e-04 - val_mae: 0.0165
# Epoch 15/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0010 - mae: 0.0196 - val_loss: 6.2234e-04 - val_mae: 0.0165
# Epoch 16/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.9772e-04 - mae: 0.0207 - val_loss: 6.1713e-04 - val_mae: 0.0155
# Epoch 17/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.2003e-04 - mae: 0.0182 - val_loss: 5.3712e-04 - val_mae: 0.0153
# Epoch 18/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.6927e-04 - mae: 0.0203 - val_loss: 0.0020 - val_mae: 0.0237
# Epoch 19/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0015 - mae: 0.0253 - val_loss: 5.2458e-04 - val_mae: 0.0151
# Epoch 20/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.3049e-04 - mae: 0.0169 - val_loss: 5.0421e-04 - val_mae: 0.0162
# Epoch 21/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.6818e-04 - mae: 0.0203 - val_loss: 0.0010 - val_mae: 0.0185
# Epoch 22/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.1304e-04 - mae: 0.0166 - val_loss: 4.5690e-04 - val_mae: 0.0148
# Epoch 23/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.6371e-04 - mae: 0.0169 - val_loss: 7.5032e-04 - val_mae: 0.0172
# Epoch 24/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.3625e-04 - mae: 0.0160 - val_loss: 3.2275e-04 - val_mae: 0.0123
# Epoch 25/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.3594e-04 - mae: 0.0164 - val_loss: 3.5969e-04 - val_mae: 0.0128
# Epoch 26/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.8513e-04 - mae: 0.0157 - val_loss: 8.8338e-04 - val_mae: 0.0205
# Epoch 27/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.7119e-04 - mae: 0.0178 - val_loss: 8.8201e-04 - val_mae: 0.0175
# Epoch 28/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.8624e-04 - mae: 0.0174 - val_loss: 0.0015 - val_mae: 0.0275
# Epoch 29/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.8887e-04 - mae: 0.0194 - val_loss: 3.8816e-04 - val_mae: 0.0125
# Epoch 30/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.7809e-04 - mae: 0.0158 - val_loss: 8.9145e-04 - val_mae: 0.0205
# Epoch 31/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.7811e-04 - mae: 0.0175 - val_loss: 2.9136e-04 - val_mae: 0.0118
# Epoch 32/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.7942e-04 - mae: 0.0154 - val_loss: 3.3060e-04 - val_mae: 0.0114
# Epoch 33/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.4095e-04 - mae: 0.0165 - val_loss: 5.3577e-04 - val_mae: 0.0164
# Epoch 34/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.1925e-04 - mae: 0.0190 - val_loss: 2.8194e-04 - val_mae: 0.0110
# Epoch 35/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9963e-04 - mae: 0.0158 - val_loss: 3.5363e-04 - val_mae: 0.0129
# Epoch 36/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.1234e-04 - mae: 0.0139 - val_loss: 2.9656e-04 - val_mae: 0.0115
# Epoch 37/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.3104e-04 - mae: 0.0158 - val_loss: 2.9575e-04 - val_mae: 0.0111
# Epoch 38/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.8834e-04 - mae: 0.0149 - val_loss: 3.5651e-04 - val_mae: 0.0123
# Epoch 39/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0128e-04 - mae: 0.0125 - val_loss: 3.1844e-04 - val_mae: 0.0119
# Epoch 40/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.0814e-04 - mae: 0.0143 - val_loss: 2.5346e-04 - val_mae: 0.0103
# Epoch 41/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9382e-04 - mae: 0.0141 - val_loss: 7.4817e-04 - val_mae: 0.0161
# Epoch 42/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.3248e-04 - mae: 0.0159 - val_loss: 3.2301e-04 - val_mae: 0.0120
# Epoch 43/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.6081e-04 - mae: 0.0122 - val_loss: 2.4409e-04 - val_mae: 0.0107
# Epoch 44/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1240e-04 - mae: 0.0124 - val_loss: 5.7971e-04 - val_mae: 0.0144
# Epoch 45/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.6508e-04 - mae: 0.0132 - val_loss: 2.3357e-04 - val_mae: 0.0104
# Epoch 46/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.9284e-04 - mae: 0.0141 - val_loss: 3.5674e-04 - val_mae: 0.0136
# Epoch 47/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 9.0282e-04 - mae: 0.0178 - val_loss: 5.9448e-04 - val_mae: 0.0145
# Epoch 48/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.5663e-04 - mae: 0.0172 - val_loss: 3.3483e-04 - val_mae: 0.0125
# Epoch 49/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.1569e-04 - mae: 0.0147 - val_loss: 2.7803e-04 - val_mae: 0.0116
# Epoch 50/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.4725e-04 - mae: 0.0144 - val_loss: 3.5196e-04 - val_mae: 0.0132

# %%
# Ensure the model is built and called with a sample batch
sample_batch = X_train[:1]  # Take the first sample batch
_ = cnn(sample_batch)  # Call the model with the sample batch

# Extract feature model (everything before the last layer)
feature_extractor = Model(inputs=cnn.inputs, outputs=cnn.get_layer("feature_layer").output)

# Extract features for training XGBoost
X_train_cnn_features = feature_extractor.predict(X_train)
X_test_cnn_features = feature_extractor.predict(X_test)

print("Extracted CNN Features Shape:", X_train_cnn_features.shape)  # Should be (num_samples, 32)
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# C:\Users\Aleix\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(32, 30, 12))
#   warnings.warn(msg)
# C:\Users\Aleix\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 30, 12))
#   warnings.warn(msg)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Extracted CNN Features Shape: (1063, 32)

# %%
# Train XGBoost on CNN features
xgb_model = xgb.XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=5, random_state=42)
xgb_model.fit(X_train_cnn_features, y_train)

# Make predictions
y_pred_xgb = xgb_model.predict(X_test_cnn_features)

# Inverse transform predictions
y_pred_xgb_rescaled = target_scaler.inverse_transform(y_pred_xgb.reshape(-1, 1))
y_test_rescaled = target_scaler.inverse_transform(y_test.reshape(-1, 1))
# Compute evaluation metrics
mse = mean_squared_error(y_test_rescaled, y_pred_xgb_rescaled)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_rescaled, y_pred_xgb_rescaled)
r2 = r2_score(y_test_rescaled, y_pred_xgb_rescaled)

# Print results
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"R-squared (R²) Score: {r2:.4f}")

# Plot actual vs predicted values
plt.figure(figsize=(12, 6))
plt.plot(y_test_rescaled, label="Actual")
plt.plot(y_pred_xgb_rescaled, label="Predicted", linestyle="dashed")
plt.title("Actual vs Predicted Prices")
plt.legend()


plt.show()
# Out:
# Mean Squared Error (MSE): 0.0002
# Root Mean Squared Error (RMSE): 0.0140
# Mean Absolute Error (MAE): 0.0091
# R-squared (R²) Score: 0.9964
